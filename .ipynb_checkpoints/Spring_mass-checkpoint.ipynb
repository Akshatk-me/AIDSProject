# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import Ridge
from sklearn.linear_model import LinearRegression
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, ExpSineSquared, WhiteKernel
from sklearn.model_selection import train_test_split
from sklearn.kernel_ridge import KernelRidge
import tensorflow as tf
# Out:
# 2024-11-25 19:56:05.276065: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-11-25 19:56:05.281023: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-11-25 19:56:05.299184: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1732544765.330503   63797 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1732544765.339691   63797 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# Constants for the damped spring-mass system
m = 1.0  # Mass (kg)
c = 0.2  # Damping coefficient (kg/s)
k = 5.0  # Spring constant (N/m)
x0 = 1.0  # Initial displacement (m)
v0 = 0.0  # Initial velocity (m/s)
time_end = 20  # End time for simulation (seconds)

# Define the system of equations for the damped spring-mass system
def damped_spring_mass(t, y):
    x, v = y
    dxdt = v
    dvdt = -(c / m) * v - (k / m) * x
    return [dxdt, dvdt]

# Time vector for the full plot
time = np.linspace(0, time_end, 1000)  # 1000 time points for smooth curve

# Solve the system numerically
solution = solve_ivp(
    damped_spring_mass,
    [0, time_end],
    [x0, v0],
    t_eval=time,
    method='RK45'
)

# Extract displacement (x) over time
x = solution.y[0]

# Sample 15 data points from the plot (evenly spaced in time, up to 5 seconds)
sample_times = np.linspace(0, 5, 15)  # Sample points from 0 to 5 seconds
sample_displacements = np.interp(sample_times, time, x)

# Add noise to the sampled data
noise = np.random.normal(0, 0.1, size=sample_displacements.shape)  # Noise with std dev of 0.1
noisy_sample_displacements = sample_displacements + noise

# Plot the displacement vs time curve (until 20 seconds)
plt.plot(time, x, label='Numerical Solution (Displacement)', color='blue', lw=2)

# Plot the noisy training data points (until 5 seconds)
plt.scatter(sample_times, noisy_sample_displacements, color='red', label='Training Data (Noisy)', zorder=5)

# Labels and title
plt.xlabel('Time (seconds)')
plt.ylabel('Displacement (m)')
plt.title('Damped Spring-Mass System')
plt.legend()

# Show plot
plt.grid(True)
plt.show()

# %%
# Reshape the data for the models
X_train = sample_times.reshape(-1, 1)  # Reshape for sklearn input
y_train = noisy_sample_displacements  # Target temperatures

# 1. Polynomial Regression (Non-Linear Regression)
poly = PolynomialFeatures(degree=2)  # Degree of the polynomial
X_poly = poly.fit_transform(X_train)  # Transform the input to higher dimensions (polynomial features)

# Train a Linear Regression on the polynomial features
poly_model = LinearRegression()
poly_model.fit(X_poly, y_train)

# Predict using the polynomial model for the entire time range (0-1000 seconds)
X_poly_full = poly.transform(time.reshape(-1, 1))  # Transform time values to polynomial features
predicted_temperatures_poly = poly_model.predict(X_poly_full)

# 2. Polynomial Ridge Regression (Non-Linear Regression with L2 Regularization)
ridge_poly_model = Ridge(alpha=0.01)  # alpha controls the strength of regularization
ridge_poly_model.fit(X_poly, y_train)

# Predict using the polynomial Ridge regression model
predicted_temperatures_ridge_poly = ridge_poly_model.predict(X_poly_full)

# Plot the equation-based curve and the model predictions
plt.plot(time, x, label="Numerical Solution", color='blue', lw=2)
plt.scatter(sample_times, noisy_sample_displacements, color='red', label="Training Data (Noisy)", zorder=5)
plt.plot(time, predicted_temperatures_poly, label="Polynomial Regression (Non-Linear)", color='green', lw=2)
plt.plot(time, predicted_temperatures_ridge_poly, label="Polynomial Ridge Regression (L2 Regularization)", color='orange', lw=2)

# Labels and title
plt.xlabel('Time (seconds)')
plt.ylabel('Displacement (m)')
plt.title("Damped Oscillation Over Time: Polynomial Regression vs Polynomial Ridge Regression")
plt.legend()

# Show plot
plt.grid(True)
plt.show()

# %%
# Test data (fine-grained grid for smooth plotting)
Y_test = x.reshape(-1,1)
X_test = time.reshape(-1,1)

# Kernel Ridge Regression with Gaussian kernel (RBF)
krr = KernelRidge(kernel="rbf", alpha=0.1, gamma=5)  # gamma controls kernel width
krr.fit(X_train, y_train)
y_krr = krr.predict(X_test)

# Gaussian Process Regression with periodic kernel + RBF + white noise
kernel = (
    1.0 * ExpSineSquared(length_scale=1.0, periodicity=2 * np.pi)
    + 0.1 * RBF(length_scale=1.0)
    + 0.1 * WhiteKernel(noise_level=0.1)
)
gpr = GaussianProcessRegressor(kernel=kernel, n_restarts_optimizer=10, random_state=42)
gpr.fit(X_train, y_train)
y_gpr, y_std = gpr.predict(X_test, return_std=True)

# Plotting the results
plt.figure(figsize=(10, 6))

# Plot training data
plt.scatter(X_train, y_train, color="red", label="Training Data (Noisy)", zorder=5)

# Plot true function
plt.plot(X_test, Y_test, color="green", label="True Function: cos(x)", linestyle="--")

# Plot Kernel Ridge Regression result
plt.plot(X_test, y_krr, color="blue", label="Kernel Ridge Regression", lw=2)

# Plot Gaussian Process Regression result
plt.plot(X_test, y_gpr, color="purple", label="Gaussian Process Regression", lw=2)
plt.fill_between(
    X_test.ravel(),
    y_gpr - 2 * y_std,
    y_gpr + 2 * y_std,
    color="purple",
    alpha=0.2,
    label="GPR ± 2σ",
)

# Labels and legend
plt.xlabel("x")
plt.ylabel("y")
plt.title("Kernel Ridge vs Gaussian Process Regression on Noisy data from Damped Oscillator")
plt.legend()
plt.grid(True)
plt.show()

# %%
X_test.shape
# Out:
# (1000, 1)

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.preprocessing import StandardScaler

# Normalize the input data (scaling the data for the neural network)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)

# 1. Vanilla Neural Network (No Regularization)
nn_model = MLPRegressor(hidden_layer_sizes=(10,), max_iter=10000, activation='relu', solver='adam', random_state=42)
nn_model.fit(X_train_scaled, y_train)

# Predict using the vanilla neural network for the entire time range (0-1000 seconds)
X_scaled_full = scaler.transform(time.reshape(-1, 1))  # Scale the entire time range
predicted_temperatures_nn = nn_model.predict(X_scaled_full)

# 2. Neural Network with L2 Regularization (Ridge-like behavior)
nn_model_l2 = MLPRegressor(hidden_layer_sizes=(10,), max_iter=10000, activation='relu', solver='adam', random_state=42, alpha=0.1)
nn_model_l2.fit(X_train_scaled, y_train)

# Predict using the L2-regularized neural network for the entire time range
predicted_temperatures_nn_l2 = nn_model_l2.predict(X_scaled_full)

# Plot the equation-based curve and the model predictions
plt.plot(time, x, label="Damped Osscilation", color='blue', lw=2)
plt.scatter(sample_times, S_train, color='red', label="Training Data (Noisy)", zorder=5)
plt.plot(time, predicted_temperatures_nn, label="Vanilla Neural Network", color='green', lw=2)
plt.plot(time, predicted_temperatures_nn_l2, label="Neural Network with L2 Regularization", color='orange', lw=2)

# Labels and title
plt.xlabel('Time (seconds)')
plt.ylabel('Temperature (°C)')
plt.title("Coffee Cooling Over Time: Neural Network vs L2 Regularized Neural Network")
plt.legend()

# Show plot
plt.grid(True)
plt.show()
# so we can see that till datapoints it perfectly following the cooling equation but after that its just going completely wrong

# %%
# Neural Network Model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(64, activation='relu', input_shape=(1,)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(1)  # Single output
])

# Compile the model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
              loss='mse',  # Mean Squared Error
              metrics=['mae'])  # Mean Absolute Error


X_test_new , X_val, y_test_new, y_val = train_test_split(X_test, Y_test, test_size=0.02, random_state=42)


# Train the model
history = model.fit(X_train, y_train, validation_data=(X_val, y_val),
                    epochs=500, batch_size=16, verbose=0)

y_test_pred = model.predict(X_test)
# Plotting the results
plt.figure(figsize=(10, 6))

# Plot training data
plt.scatter(X_train, y_train, color='red', label='Training Data (Noisy)', zorder=5)

# Plot true function
plt.plot(X_test, Y_test , color='green', label='True Function: sin(x)', linestyle='--')

# Plot Neural Network prediction
plt.plot(X_test, y_test_pred, color='blue', label='Neural Network Prediction', lw=2)

# Labels and legend
plt.xlabel("x")
plt.ylabel("y")
plt.title("Neural Network Regression on Damped Oscillator")
plt.legend()
plt.grid(True)
plt.show()

# Plot loss over epochs
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable

# Constants
T_room = 25  # Room temperature (°C)
T_initial = 100  # Initial temperature of the coffee (°C)
k = 0.05  # Cooling constant (arbitrary value)
time_end = 1000  # End time for simulation (in seconds)

# Neural network architecture
class PINN(nn.Module):
    def __init__(self):
        super(PINN, self).__init__()
        self.fc1 = nn.Linear(1, 64)  # First hidden layer
        self.fc2 = nn.Linear(64, 64)  # Second hidden layer
        self.fc3 = nn.Linear(64, 1)  # Output layer

    def forward(self, t):
        x = torch.relu(self.fc1(t))
        x = torch.relu(self.fc2(x))
        return self.fc3(x)

# Physics-informed loss function (based on ODE)
def physics_informed_loss(model, t):
    t.requires_grad = True
    T = model(t)  # Predicted temperature
    T_t = torch.autograd.grad(T, t, grad_outputs=torch.ones_like(T), create_graph=True)[0]  # dT/dt
    # ODE: dT/dt = -k * (T - T_room)
    loss = torch.mean((T_t + k * (T - T_room))**2)
    return loss

# Data loss (Mean Squared Error)
def data_loss(model, t_data, T_data):
    T_pred = model(t_data)
    return torch.mean((T_pred - T_data)**2)

# Training setup
def train_PINN(model, t_data, T_data, t_physics, epochs=5000, lr=0.001):
    optimizer = optim.Adam(model.parameters(), lr=lr)
    for epoch in range(epochs):
        optimizer.zero_grad()
        
        # Data loss
        loss_data = data_loss(model, t_data, T_data)
        
        # Physics-informed loss
        loss_physics = physics_informed_loss(model, t_physics)
        
        # Total loss
        loss = loss_data + loss_physics
        
        loss.backward()
        optimizer.step()
        
        if epoch % 1000 == 0:
            print(f'Epoch {epoch}/{epochs}, Loss: {loss.item():.4e}')
    return model

# Generating the temperature data from Newton's Law of Cooling
def temperature(t):
    return T_room + (T_initial - T_room) * np.exp(-k * t)

# Uniformly sample the training data points (15 points)
sample_times = np.linspace(0, 300, 15)
sample_temperatures = temperature(sample_times)
noise = np.random.normal(0, 2, size=sample_temperatures.shape)  # Standard deviation of 2 for noise
noisy_sample_temperatures = sample_temperatures + noise

# Convert data to tensors
t_data = torch.tensor(sample_times, dtype=torch.float32).view(-1, 1)
T_data = torch.tensor(noisy_sample_temperatures, dtype=torch.float32).view(-1, 1)

# Physics sampling (training the model on the physics equation)
t_physics = torch.tensor(np.linspace(0, time_end, 1000), dtype=torch.float32).view(-1, 1)

# Initialize model
model = PINN()

# Train the model
trained_model = train_PINN(model, t_data, T_data, t_physics, epochs=10000, lr=0.001)

# Make predictions
t_full = torch.tensor(np.linspace(0, time_end, 1000), dtype=torch.float32).view(-1, 1)
predicted_temperatures_pinn = trained_model(t_full).detach().numpy()

# Plot the results
plt.plot(np.linspace(0, time_end, 1000), temperature(np.linspace(0, time_end, 1000)), label="Newton's Law of Cooling", color='blue', lw=2)
plt.scatter(sample_times, noisy_sample_temperatures, color='red', label="Training Data (Noisy)", zorder=5)
plt.plot(np.linspace(0, time_end, 1000), predicted_temperatures_pinn, label="PINN Predictions", color='green', lw=2)
plt.xlabel('Time (seconds)')
plt.ylabel('Temperature (°C)')
plt.title('PINN vs Newton\'s Law of Cooling')
plt.legend()
plt.grid(True)
plt.show()
# so we can see that by doing PINN we removed that error due to less data and it was compensated by PDE
# Out:
# Epoch 0/10000, Loss: 1.6578e+03
# Epoch 1000/10000, Loss: 3.3817e+00
# Epoch 2000/10000, Loss: 3.3140e+00
# Epoch 3000/10000, Loss: 3.3426e+00
# Epoch 4000/10000, Loss: 3.6927e+00
# Epoch 5000/10000, Loss: 3.3205e+00
# Epoch 6000/10000, Loss: 3.2735e+00
# Epoch 7000/10000, Loss: 3.2787e+00
# Epoch 8000/10000, Loss: 3.2663e+00
# Epoch 9000/10000, Loss: 3.3242e+00

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable

# Constants
T_room = 25  # Room temperature (°C)
T_initial = 100  # Initial temperature of the coffee (°C)
time_end = 1000  # End time for simulation (in seconds)

# Neural network architecture
class PINN(nn.Module):
    def __init__(self):
        super(PINN, self).__init__()
        self.fc1 = nn.Linear(1, 64)  # First hidden layer
        self.fc2 = nn.Linear(64, 64)  # Second hidden layer
        self.fc3 = nn.Linear(64, 1)  # Output layer
        self.k = nn.Parameter(torch.tensor(0.05))  # Learnable parameter for cooling constant k

    def forward(self, t):
        x = torch.relu(self.fc1(t))
        x = torch.relu(self.fc2(x))
        return self.fc3(x)

# Physics-informed loss function (based on ODE)
def physics_informed_loss(model, t):
    t.requires_grad = True
    T = model(t)  # Predicted temperature
    T_t = torch.autograd.grad(T, t, grad_outputs=torch.ones_like(T), create_graph=True)[0]  # dT/dt
    k = model.k  # Cooling constant
    # ODE: dT/dt = -k * (T - T_room)
    loss = torch.mean((T_t + k * (T - T_room))**2)
    return loss, k

# Data loss (Mean Squared Error)
def data_loss(model, t_data, T_data):
    T_pred = model(t_data)
    return torch.mean((T_pred - T_data)**2)

# Training setup
def train_PINN(model, t_data, T_data, t_physics, epochs=5000, lr=0.001):
    optimizer = optim.Adam(model.parameters(), lr=lr)
    for epoch in range(epochs):
        optimizer.zero_grad()
        
        # Data loss
        loss_data = data_loss(model, t_data, T_data)
        
        # Physics-informed loss
        loss_physics, k_estimate = physics_informed_loss(model, t_physics)
        
        # Total loss
        loss = loss_data + loss_physics
        
        loss.backward()
        optimizer.step()
        
        if epoch % 1000 == 0:
            print(f'Epoch {epoch}/{epochs}, Loss: {loss.item():.4e}, Estimated k: {k_estimate.item():.4f}')
    return model

# Generating the temperature data from Newton's Law of Cooling
def temperature(t, k):
    return T_room + (T_initial - T_room) * np.exp(-k * t)

# Uniformly sample the training data points (15 points)
sample_times = np.linspace(0, 300, 15)
true_k = 0.05  # True cooling constant
sample_temperatures = temperature(sample_times, true_k)
noise = np.random.normal(0, 2, size=sample_temperatures.shape)  # Standard deviation of 2 for noise
noisy_sample_temperatures = sample_temperatures + noise

# Convert data to tensors
t_data = torch.tensor(sample_times, dtype=torch.float32).view(-1, 1)
T_data = torch.tensor(noisy_sample_temperatures, dtype=torch.float32).view(-1, 1)

# Physics sampling (training the model on the physics equation)
t_physics = torch.tensor(np.linspace(0, time_end, 1000), dtype=torch.float32).view(-1, 1)

# Initialize model
model = PINN()

# Train the model
trained_model = train_PINN(model, t_data, T_data, t_physics, epochs=10000, lr=0.001)

# Make predictions
t_full = torch.tensor(np.linspace(0, time_end, 1000), dtype=torch.float32).view(-1, 1)
predicted_temperatures_pinn = trained_model(t_full).detach().numpy()
k_estimated = trained_model.k.item()  # Estimated cooling constant

# Plot the results
plt.plot(np.linspace(0, time_end, 1000), temperature(np.linspace(0, time_end, 1000), true_k), label="Newton's Law of Cooling (True k)", color='blue', lw=2)
plt.scatter(sample_times, noisy_sample_temperatures, color='red', label="Training Data (Noisy)", zorder=5)
plt.plot(np.linspace(0, time_end, 1000), predicted_temperatures_pinn, label="PINN Predictions", color='green', lw=2)
plt.xlabel('Time (seconds)')
plt.ylabel('Temperature (°C)')
plt.title(f'PINN vs Newton\'s Law of Cooling\nEstimated k: {k_estimated:.4f}')
plt.legend()
plt.grid(True)
plt.show()
print(k_estimated)
# we can see PINN is doing it's best but becuase no. of datapoints are too less so it's not able to perfectly get the values and diverges but still its lot correct than previous linear regression techniques 
#so here a tradeoff happens between number of datapoints more more the computational power so not much better than traditional neumerical method so we have to find that optimal spot where its give us maximum benefit
# Out:
# Epoch 0/10000, Loss: 2.4414e+03, Estimated k: 0.0490
# Epoch 1000/10000, Loss: 1.2658e+00, Estimated k: 0.0026
# Epoch 2000/10000, Loss: 9.5089e-01, Estimated k: 0.0153
# Epoch 3000/10000, Loss: 4.2953e-01, Estimated k: 0.0269
# Epoch 4000/10000, Loss: 4.1963e-01, Estimated k: 0.0292
# Epoch 5000/10000, Loss: 4.1808e-01, Estimated k: 0.0298
# Epoch 6000/10000, Loss: 4.1778e-01, Estimated k: 0.0300
# Epoch 7000/10000, Loss: 5.2087e-01, Estimated k: 0.0286
# Epoch 8000/10000, Loss: 4.2641e-01, Estimated k: 0.0306
# Epoch 9000/10000, Loss: 4.2336e-01, Estimated k: 0.0305
# 0.030694782733917236

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable

# Constants
T_room = 25  # Room temperature (°C)
T_initial = 100  # Initial temperature of the coffee (°C)
time_end = 1000  # End time for simulation (in seconds)

# Neural network architecture
class PINN(nn.Module):
    def __init__(self):
        super(PINN, self).__init__()
        self.fc1 = nn.Linear(1, 64)  # First hidden layer
        self.fc2 = nn.Linear(64, 64)  # Second hidden layer
        self.fc3 = nn.Linear(64, 1)  # Output layer
        self.k = nn.Parameter(torch.tensor(0.05))  # Learnable parameter for cooling constant k

    def forward(self, t):
        x = torch.relu(self.fc1(t))
        x = torch.relu(self.fc2(x))
        return self.fc3(x)

# Physics-informed loss function (based on ODE)
def physics_informed_loss(model, t):
    t.requires_grad = True
    T = model(t)  # Predicted temperature
    T_t = torch.autograd.grad(T, t, grad_outputs=torch.ones_like(T), create_graph=True)[0]  # dT/dt
    k = model.k  # Cooling constant
    # ODE: dT/dt = -k * (T - T_room)
    loss = torch.mean((T_t + k * (T - T_room))**2)
    return loss, k

# Data loss (Mean Squared Error)
def data_loss(model, t_data, T_data):
    T_pred = model(t_data)
    return torch.mean((T_pred - T_data)**2)

# Training setup
def train_PINN(model, t_data, T_data, t_physics, epochs=5000, lr=0.001):
    optimizer = optim.Adam(model.parameters(), lr=lr)
    for epoch in range(epochs):
        optimizer.zero_grad()
        
        # Data loss
        loss_data = data_loss(model, t_data, T_data)
        
        # Physics-informed loss
        loss_physics, k_estimate = physics_informed_loss(model, t_physics)
        
        # Total loss
        loss = loss_data + loss_physics
        
        loss.backward()
        optimizer.step()
        
        if epoch % 1000 == 0:
            print(f'Epoch {epoch}/{epochs}, Loss: {loss.item():.4e}, Estimated k: {k_estimate.item():.4f}')
    return model

# Generating the temperature data from Newton's Law of Cooling
def temperature(t, k):
    return T_room + (T_initial - T_room) * np.exp(-k * t)

# Uniformly sample the training data points (15 points)
sample_times = np.linspace(0, 300, 30)
true_k = 0.05  # True cooling constant
sample_temperatures = temperature(sample_times, true_k)
noise = np.random.normal(0, 2, size=sample_temperatures.shape)  # Standard deviation of 2 for noise
noisy_sample_temperatures = sample_temperatures + noise

# Convert data to tensors
t_data = torch.tensor(sample_times, dtype=torch.float32).view(-1, 1)
T_data = torch.tensor(noisy_sample_temperatures, dtype=torch.float32).view(-1, 1)

# Physics sampling (training the model on the physics equation)
t_physics = torch.tensor(np.linspace(0, time_end, 1000), dtype=torch.float32).view(-1, 1)

# Initialize model
model = PINN()

# Train the model
trained_model = train_PINN(model, t_data, T_data, t_physics, epochs=10000, lr=0.001)

# Make predictions
t_full = torch.tensor(np.linspace(0, time_end, 1000), dtype=torch.float32).view(-1, 1)
predicted_temperatures_pinn = trained_model(t_full).detach().numpy()
k_estimated = trained_model.k.item()  # Estimated cooling constant

# Plot the results
plt.plot(np.linspace(0, time_end, 1000), temperature(np.linspace(0, time_end, 1000), true_k), label="Newton's Law of Cooling (True k)", color='blue', lw=2)
plt.scatter(sample_times, noisy_sample_temperatures, color='red', label="Training Data (Noisy)", zorder=5)
plt.plot(np.linspace(0, time_end, 1000), predicted_temperatures_pinn, label="PINN Predictions", color='green', lw=2)
plt.xlabel('Time (seconds)')
plt.ylabel('Temperature (°C)')
plt.title(f'PINN vs Newton\'s Law of Cooling\nEstimated k: {k_estimated:.4f}')
plt.legend()
plt.grid(True)
plt.show()
print(k_estimated)
# Out:
# Epoch 0/10000, Loss: 1.0196e+03, Estimated k: 0.0490
# Epoch 1000/10000, Loss: 2.6105e+00, Estimated k: 0.0306
# Epoch 2000/10000, Loss: 2.5620e+00, Estimated k: 0.0481
# Epoch 3000/10000, Loss: 2.5715e+00, Estimated k: 0.0469
# Epoch 4000/10000, Loss: 2.5488e+00, Estimated k: 0.0451
# Epoch 5000/10000, Loss: 2.6313e+00, Estimated k: 0.0467
# Epoch 6000/10000, Loss: 2.6190e+00, Estimated k: 0.0446
# Epoch 7000/10000, Loss: 2.7427e+00, Estimated k: 0.0432
# Epoch 8000/10000, Loss: 3.9250e+00, Estimated k: 0.0455
# Epoch 9000/10000, Loss: 2.5059e+00, Estimated k: 0.0532
# 0.053616221994161606

# %%
# Out:
# (15, 3)
